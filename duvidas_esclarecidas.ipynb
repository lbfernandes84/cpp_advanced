// %% [markdown]
// Qual o significado da palavra public na frente da classe pai a ser herdada por uma outra classe?

// %%
class Parent{    
};

class Child: public Parent//Qual o significado disso?
{
};
